# %%
vowels = ['a','e','i','o','u']

# %%
vowels.append("halts mol")
print(vowels[5])
# Out:
# halts mol

# %%
vowels.insert(1,"be quiet")
print(vowels[1])
# Out:
# be quiet

# %%
for x in vowels :print(x.capitalize())
# Out:
# A
# Be quiet
# E
# I
# O
# U
# Halts mol

# %%
sentence = input("Enter String : ")
if 't' or 'T' not in sentence : sentence += 't'
print(sentence)
# Out:
# Asadast

# %%
import xml.etree.ElementTree as ET
cdata_msg = "<errorMsg><![CDATA[...]]></errorMsg><stackTrace><![CDATA[...]]></stackTrace>"
# Assume the CDATA message is stored in the variable 'cdata_msg'
root = ET.fromstring('<root>' + cdata_msg + '</root>')
error_msg = root.text.strip()

print(error_msg)
